# %% [markdown]
# ## Librerias

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import seaborn as sns

# %% [markdown]
# ## Calling Excel

# %% [markdown]
# Importamos la base de datos del excel Precios Indexados.

# %%
precio_indexado_df = pd.read_excel("../Data/BD_Precios_Indexados.xlsx", engine='openpyxl')

# %%
precio_indexado_df
# Out:
#     Comercializadora  Tarifa  Precio_Potencia_P1  Precio_Potencia_P2  \
# 0             Opcion  2.0. A           38.043426                 NaN
# 1             Opcion  2.0. A           38.043426                 NaN
# 2             Opcion  2.0. A           38.043426                 NaN
# 3             Opcion  2.0. A           38.043426                 NaN
# 4             Opcion  2.0. A           38.043426                 NaN
# ..               ...     ...                 ...                 ...
# 866              CYE  6.1. A           39.139427           19.586654
# 867              CYE  6.1. A           39.139427           19.586654
# 868              CYE  6.1. A           39.139427           19.586654
# 869              CYE  6.1. A           39.139427           19.586654
# 870              CYE  6.1. A           39.139427           19.586654
#
#      Precio_Potencia_P3  Precio_Potencia_P4  Precio_Potencia_P5  \
# 0                   NaN           38.043426                 NaN
# ...

# %% [markdown]
# ## Exploring Data

# %%
precio_indexado_df.dtypes
# Out:
# Comercializadora       object
# Tarifa                 object
# Precio_Potencia_P1    float64
# Precio_Potencia_P2    float64
# Precio_Potencia_P3    float64
# Precio_Potencia_P4    float64
# Precio_Potencia_P5    float64
# Precio_Potencia_P6    float64
# Precio_Energía_P1     float64
# Precio_Energía_P2     float64
# Precio_Energía_P3     float64
# Precio_Energía_P4     float64
# Precio_Energía_P5     float64
# Precio_Energía_P6     float64
# Fecha_Inicio           object
# Fecha_Finalización     object
# dtype: object

# %%
precio_indexado_df.isna().sum()
# Out:
# Comercializadora        0
# Tarifa                  0
# Precio_Potencia_P1      0
# Precio_Potencia_P2    468
# Precio_Potencia_P3    468
# Precio_Potencia_P4      0
# Precio_Potencia_P5    468
# Precio_Potencia_P6    468
# Precio_Energía_P1      96
# Precio_Energía_P2      96
# Precio_Energía_P3     345
# Precio_Energía_P4     111
# Precio_Energía_P5     121
# Precio_Energía_P6     267
# Fecha_Inicio            0
# Fecha_Finalización      0
# dtype: int64

# %%
precio_indexado_df.describe()
# Out:
#        Precio_Potencia_P1  Precio_Potencia_P2  Precio_Potencia_P3  \
# count          871.000000          403.000000          403.000000
# mean            41.859855           24.534441           12.070127
# std              8.884251            8.921031            3.642533
# min             22.158348           11.088763            8.115134
# 25%             38.043426           19.586654            8.367731
# 50%             40.728885           24.437330           14.334178
# 75%             44.444710           36.490689           16.291555
# max             59.173468           36.490689           16.291555
#
#        Precio_Potencia_P4  Precio_Potencia_P5  Precio_Potencia_P6  \
# count          871.000000          403.000000          403.000000
# mean            38.025729           22.779753            9.466395
# std             14.371058           10.524486            4.685616
# min              8.115134            8.115134            3.702649
# ...

# %%
sns.pairplot(precio_indexado_df)

# %%
precio_indexado_df.corr()
# Out:
#                     Precio_Potencia_P1  Precio_Potencia_P2  \
# Precio_Potencia_P1            1.000000            0.986660
# Precio_Potencia_P2            0.986660            1.000000
# Precio_Potencia_P3           -0.180794           -0.203497
# Precio_Potencia_P4            0.850273            0.956155
# Precio_Potencia_P5            0.948506            0.987210
# Precio_Potencia_P6            0.233309            0.306967
# Precio_Energía_P1            -0.205627           -0.166885
# Precio_Energía_P2            -0.032392           -0.039539
# Precio_Energía_P3            -0.260420           -0.137296
# Precio_Energía_P4            -0.142390            0.204285
# Precio_Energía_P5             0.003602            0.223740
# Precio_Energía_P6             0.023277            0.248481
#
#                     Precio_Potencia_P3  Precio_Potencia_P4  \
# Precio_Potencia_P1           -0.180794            0.850273
# Precio_Potencia_P2           -0.203497            0.956155
# ...

# %%
precio_indexado_df["Comercializadora"].unique()
# Out:
# array(['Opcion', 'Audax', 'Sun_Air_One', 'CYE'], dtype=object)

# %%
precio_indexado_df["Tarifa"].unique()
# Out:
# array(['2.0. A', '2.0. DHA', '2.1. A', '2.1. DHA', '3.0. A', '3.1. A',
#        '6.1. A', '6.2. A'], dtype=object)

# %%
precio_indexado_df["Fecha_Inicio"].unique()
# Out:
# array(['01.01.2018', '01.02.2018', '01.03.2018', '01.04.2018',
#        '01.05.2018', '01.06.2018', '01.07.2018', '01.08.2018',
#        '01.09.2018', '01.10.2018', '01.11.2018', '01.12.2018',
#        '01.01.2019', '01.02.2019', '01.03.2019', '01.04.2019',
#        '01.05.2019', '01.06.2019', '01.07.2019', '01.08.2019',
#        '01.09.2019', '01.10.2019', '01.11.2019', '01.12.2019',
#        '01.01.2020', '01.02.2020', '01.03.2020', '01.04.2020',
#        '01.05.2020', '01.06.2020', '01.07.2020', '01.08.2020',
#        '01.09.2020', '01.10.2020', '01.11.2020'], dtype=object)

# %%
precio_indexado_df["Fecha_Finalización"].unique()
# Out:
# array(['31.01.2018', '30.02.2018', '31.03.2018', '30.04.2018',
#        '31.05.2018', '30.06.2018', '31.07.2018', '31.08.2018',
#        '30.09.2018', '31.10.2018', '30.11.2018', '31.12.2018',
#        '31.01.2019', '30.02.2019', '31.03.2019', '30.04.2019',
#        '31.05.2019', '30.06.2019', '31.07.2019', '31.08.2019',
#        '30.09.2019', '31.10.2019', '30.11.2019', '31.12.2019',
#        '31.01.2020', '30.02.2020', '31.03.2020', '30.04.2020',
#        '31.05.2020', '30.06.2020', '31.07.2020', '31.08.2020',
#        '30.09.2020', '31.10.2020', '30.11.2020'], dtype=object)

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# #### Managing NaN

# %% [markdown]
# First we substitue the Price NaNs for value 0, as those NaN represent a period where the client will not be charged by the electricity.
# or
# we dont touch the NaNs as they will allow us to indentify when their has been an error better than with a 0.

# %% [markdown]
# Then we create a function that adds the NaN values of Fecha_Finalización with the last date from the column Fecha_Inicio grouping_by the same column "Comercializadora"

# %% [markdown]
# Changing "Date" column from object to date type:

# %% [markdown]
# #### Changing all "Precio" columns values  that are  MWh/€ to KWh/€

# %% [markdown]
# All values higher than 0 we divide by 1000 to transform to KWh.
