# %% [markdown]
# Una vez firmado el contrato. Se tienen que ir archivando una base de datos del cliente, con la información del proceso, consumo, precio contratado, etc.

# %% [markdown]
# ## Librerías

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import seaborn as sns

# %% [markdown]
# ## Calling Excel

# %%
clientes = pd.read_excel("../Data/BD_Clientes.xlsx", engine='openpyxl')
clientes
# Out:
#                            Cliente:              Unnamed: 1 Unnamed: 2  \
# 0                               NaN                     NaN        NaN
# 1           Información del cliente                     NaN        NaN
# 2                           Cliente    Titular de la Cuenta  CIF / NIF
# 3                           Cliente    Titular de la Cuenta  CIF / NIF
# 4                       La Estrella             Azaya, S.L.  B28350619
# ..                              ...                     ...        ...
# 93         Jimena Lopez de la Serna  Jayga Inversiones S.A.  B84257567
# 94  Fernando Olazabal - Lavanderías       DYNASET AEREA AIE  V02645208
# 95                     Sonia Casado       VACIASILOS 05 S.L  B84535327
# 96                     Sonia Casado       VACIASILOS 05 S.L  B84535327
# 97                     Sonia Casado       VACIASILOS 05 S.L  B84535327
#
#                  Unnamed: 3   Unnamed: 4                 Establecimiento:  \
# ...

# %% [markdown]
# ## DF a SQL
