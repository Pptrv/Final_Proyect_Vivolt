# %% [markdown]
# ## Librerias

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Calling Excel

# %%
precio_fijo_df = pd.read_excel("../Data/excel/BD_Precios_Fijos.xlsx", engine='openpyxl')

# %%
precio_fijo_df
# Out:
#     Comercializadora    Tarifa  Precio_Potencia_P1  Precio_Potencia_P2  \
# 0                CYE    2.0. A           38.043426           38.043426
# 1                CYE  2.0. DHA           38.043426           38.043426
# 2                CYE    2.1. A           44.444710           44.444710
# 3                CYE  2.1. DHA           44.444710           44.444710
# 4                CYE    3.0. A           40.728885           24.437330
# ..               ...       ...                 ...                 ...
# 157           Opcion  2.0. DHA           38.043426           38.043426
# 158           Opcion    2.1. A           44.444710           44.444710
# 159           Opcion  2.1. DHA           44.444710           44.444710
# 160           Opcion    3.0. A           40.728885           24.437330
# 161           Opcion    3.1. A           59.173468           36.490689
#
#      Precio_Potencia_P3  Precio_Potencia_P4  Precio_Potencia_P5  \
# ...

# %% [markdown]
# ## Exploring Data

# %%
precio_fijo_df.dtypes
# Out:
# Comercializadora       object
# Tarifa                 object
# Precio_Potencia_P1    float64
# Precio_Potencia_P2    float64
# Precio_Potencia_P3    float64
# Precio_Potencia_P4    float64
# Precio_Potencia_P5    float64
# Precio_Potencia_P6    float64
# Precio_Energía_P1     float64
# Precio_Energía_P2     float64
# Precio_Energía_P3     float64
# Precio_Energía_P4     float64
# Precio_Energía_P5     float64
# Precio_Energía_P6     float64
# Fecha_Inicio           object
# Fecha_Finalización     object
# dtype: object

# %%
precio_fijo_df.isna().sum()
# Out:
# Comercializadora       0
# Tarifa                 0
# Precio_Potencia_P1     0
# Precio_Potencia_P2     0
# Precio_Potencia_P3     0
# Precio_Potencia_P4     0
# Precio_Potencia_P5     0
# Precio_Potencia_P6     0
# Precio_Energía_P1      0
# Precio_Energía_P2      0
# Precio_Energía_P3     54
# Precio_Energía_P4      0
# Precio_Energía_P5      0
# Precio_Energía_P6     54
# Fecha_Inicio           0
# Fecha_Finalización    24
# dtype: int64

# %%
precio_fijo_df.describe()
# Out:
#        Precio_Potencia_P1  Precio_Potencia_P2  Precio_Potencia_P3  \
# count          162.000000          162.000000          162.000000
# mean            44.146437           37.650715           31.605926
# std              7.235349            6.711091           14.109503
# min             38.043426           24.437330            8.367731
# 25%             38.043426           36.490689           16.291555
# 50%             42.586798           38.043426           38.043426
# 75%             44.444710           44.444710           44.444710
# max             59.173468           44.444710           44.444710
#
#        Precio_Potencia_P4  Precio_Potencia_P5  Precio_Potencia_P6  \
# count          162.000000          162.000000          162.000000
# mean            44.146437           37.650715           31.605926
# std              7.235349            6.711091           14.109503
# min             38.043426           24.437330            8.367731
# ...

# %%
sns.pairplot(precio_fijo_df)

# %%
precio_fijo_df.corr()
# Out:
#                     Precio_Potencia_P1  Precio_Potencia_P2  \
# Precio_Potencia_P1            1.000000            0.093199
# Precio_Potencia_P2            0.093199            1.000000
# Precio_Potencia_P3           -0.604165            0.724046
# Precio_Potencia_P4            1.000000            0.093199
# Precio_Potencia_P5            0.093199            1.000000
# Precio_Potencia_P6           -0.604165            0.724046
# Precio_Energía_P1            -0.108141            0.131620
# Precio_Energía_P2            -0.044589            0.073416
# Precio_Energía_P3            -0.160226            0.241948
# Precio_Energía_P4            -0.108141            0.131620
# Precio_Energía_P5            -0.044589            0.073416
# Precio_Energía_P6            -0.160226            0.241948
#
#                     Precio_Potencia_P3  Precio_Potencia_P4  \
# Precio_Potencia_P1           -0.604165            1.000000
# Precio_Potencia_P2            0.724046            0.093199
# ...

# %%
precio_fijo_df["Comercializadora"].unique()
# Out:
# array(['CYE', 'Sun_Air_One', 'Audax', 'Opcion'], dtype=object)

# %%
precio_fijo_df["Tarifa"].unique()
# Out:
# array(['2.0. A', '2.0. DHA', '2.1. A', '2.1. DHA', '3.0. A', '3.1. A'],
#       dtype=object)

# %%
precio_fijo_df["Fecha_Inicio"].unique()
# Out:
# array(['16.11.2020', '11.06.2020', '08.09.2020', '05.08.2020',
#        '17.11.2020', '01.12.2020', '03.11.2020', '05.10.2020',
#        '06.07.2020', '01.05.2020', '01.04.2020', '01.03.2020',
#        '01.02.2020', '01.01.2020', '01.12.2019', '01.11.2019',
#        '01.10.2019', '01.09.2019', '01.08.2019', '01.07.2019',
#        '01.06.2019', '01.05.2019', '01.04.2019'], dtype=object)

# %%
precio_fijo_df["Fecha_Finalización"].unique()
# Out:
# array([nan, '16.11.2020', '08.09.2020', '17.11.2020', '01.12.2020',
#        '03.11.2020', '05.10.2020', '05.08.2020', '06.07.2020',
#        '11.06.2020', '01.05.2020', '01.04.2020', '01.03.2020',
#        '01.02.2020', '01.01.2020', '01.12.2019', '01.11.2019',
#        '01.10.2019', '01.09.2019', '01.08.2019', '01.07.2019',
#        '01.06.2019', '01.05.2019', '01.04.2019'], dtype=object)

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# #### Managing NaN

# %% [markdown]
# First we substitue the "Precio", "Fecha_Finalización" and "Comercializadora" NaNs for value 0.
# The idea is to look for the value 0 in the column of dates when we look for a date to perform the analisis.

# %%
precio_fijo_df.replace(np.nan, 0, inplace=True)

# %%
precio_fijo_df.isna().sum()
# Out:
# Comercializadora      0
# Tarifa                0
# Precio_Potencia_P1    0
# Precio_Potencia_P2    0
# Precio_Potencia_P3    0
# Precio_Potencia_P4    0
# Precio_Potencia_P5    0
# Precio_Potencia_P6    0
# Precio_Energía_P1     0
# Precio_Energía_P2     0
# Precio_Energía_P3     0
# Precio_Energía_P4     0
# Precio_Energía_P5     0
# Precio_Energía_P6     0
# Fecha_Inicio          0
# Fecha_Finalización    0
# dtype: int64

# %% [markdown]
# or, we live the NaN values as it will show when a factura de luz has not been inserted properly and when looking for "Fecha_Finalización" and "Comercializadora" we can search for value NaN instead of 0.

# %% [markdown]
# Changing "Date" column from object to date type:

# %%
precio_fijo_df['Fecha_Inicio'] = pd.to_datetime(precio_fijo_df['Fecha_Inicio'])

# %%
precio_fijo_df['Fecha_Finalización'] = pd.to_datetime(precio_fijo_df['Fecha_Finalización'])

# %%
precio_fijo_df.dtypes
# Out:
# Comercializadora              object
# Tarifa                        object
# Precio_Potencia_P1           float64
# Precio_Potencia_P2           float64
# Precio_Potencia_P3           float64
# Precio_Potencia_P4           float64
# Precio_Potencia_P5           float64
# Precio_Potencia_P6           float64
# Precio_Energía_P1            float64
# Precio_Energía_P2            float64
# Precio_Energía_P3            float64
# Precio_Energía_P4            float64
# Precio_Energía_P5            float64
# Precio_Energía_P6            float64
# Fecha_Inicio          datetime64[ns]
# Fecha_Finalización    datetime64[ns]
# dtype: object

# %% [markdown]
# #### Changing all "Precio" columns values  that are  MWh/€ to KWh/€

# %% [markdown]
# All price values higher than 0 we divide by 1000 to transform to KWh.

# %%
precio_fijo_df['Precio_Potencia_P1'] = precio_fijo_df['Precio_Potencia_P1'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Potencia_P2'] = precio_fijo_df['Precio_Potencia_P2'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Potencia_P3'] = precio_fijo_df['Precio_Potencia_P3'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Potencia_P4'] = precio_fijo_df['Precio_Potencia_P4'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Potencia_P5'] = precio_fijo_df['Precio_Potencia_P5'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Potencia_P6'] = precio_fijo_df['Precio_Potencia_P6'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Potencia_P6'] = precio_fijo_df['Precio_Potencia_P6'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Energía_P1'] = precio_fijo_df['Precio_Energía_P1'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Energía_P2'] = precio_fijo_df['Precio_Energía_P1'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Energía_P3'] = precio_fijo_df['Precio_Energía_P1'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Energía_P4'] = precio_fijo_df['Precio_Energía_P1'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Energía_P5'] = precio_fijo_df['Precio_Energía_P1'].apply(lambda x: x/1000 if x>0.5 else x)
precio_fijo_df['Precio_Energía_P6'] = precio_fijo_df['Precio_Energía_P1'].apply(lambda x: x/1000 if x>0.5 else x)

# %%
precio_fijo_df
# Out:
#     Comercializadora    Tarifa  Precio_Potencia_P1  Precio_Potencia_P2  \
# 0                CYE    2.0. A            0.038043            0.038043
# 1                CYE  2.0. DHA            0.038043            0.038043
# 2                CYE    2.1. A            0.044445            0.044445
# 3                CYE  2.1. DHA            0.044445            0.044445
# 4                CYE    3.0. A            0.040729            0.024437
# ..               ...       ...                 ...                 ...
# 157           Opcion  2.0. DHA            0.038043            0.038043
# 158           Opcion    2.1. A            0.044445            0.044445
# 159           Opcion  2.1. DHA            0.044445            0.044445
# 160           Opcion    3.0. A            0.040729            0.024437
# 161           Opcion    3.1. A            0.059173            0.036491
#
#      Precio_Potencia_P3  Precio_Potencia_P4  Precio_Potencia_P5  \
# ...

# %% [markdown]
# ## Save Clean Dataframe

# %%
precio_fijo_df.to_csv("../Data/csv/precio_fijo.csv")
