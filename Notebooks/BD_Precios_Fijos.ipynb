# %% [markdown]
# ## Librerias

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import seaborn as sns

# %% [markdown]
# ## Calling Excel

# %%
precio_fijo_df = pd.read_excel("../Data/BD_Precios_Fijos.xlsx", engine='openpyxl')

# %%
precio_fijo_df
# Out:
#     Comercializadora    Tarifa  Precio_Potencia_P1  Precio_Potencia_P2  \
# 0                CYE    2.0. A           38.043426           38.043426
# 1                CYE  2.0. DHA           38.043426           38.043426
# 2                CYE    2.1. A           44.444710           44.444710
# 3                CYE  2.1. DHA           44.444710           44.444710
# 4                CYE    3.0. A           40.728885           24.437330
# ..               ...       ...                 ...                 ...
# 157           Opcion  2.0. DHA           38.043426           38.043426
# 158           Opcion    2.1. A           44.444710           44.444710
# 159           Opcion  2.1. DHA           44.444710           44.444710
# 160           Opcion    3.0. A           40.728885           24.437330
# 161           Opcion    3.1. A           59.173468           36.490689
#
#      Precio_Potencia_P3  Precio_Potencia_P4  Precio_Potencia_P5  \
# ...

# %% [markdown]
# ## Exploring Data

# %%
precio_fijo_df.dtypes
# Out:
# Comercializadora       object
# Tarifa                 object
# Precio_Potencia_P1    float64
# Precio_Potencia_P2    float64
# Precio_Potencia_P3    float64
# Precio_Potencia_P4    float64
# Precio_Potencia_P5    float64
# Precio_Potencia_P6    float64
# Precio_Energía_P1     float64
# Precio_Energía_P2     float64
# Precio_Energía_P3     float64
# Precio_Energía_P4     float64
# Precio_Energía_P5     float64
# Precio_Energía_P6     float64
# Fecha Inicio           object
# Fecha Finalización     object
# dtype: object

# %%
precio_fijo_df.isna().sum()
# Out:
# Comercializadora        0
# Tarifa                  0
# Precio_Potencia_P1      0
# Precio_Potencia_P2    108
# Precio_Potencia_P3    108
# Precio_Potencia_P4      0
# Precio_Potencia_P5    108
# Precio_Potencia_P6    108
# Precio_Energía_P1       0
# Precio_Energía_P2       0
# Precio_Energía_P3      54
# Precio_Energía_P4       0
# Precio_Energía_P5       0
# Precio_Energía_P6      54
# Fecha Inicio            0
# Fecha Finalización     24
# dtype: int64

# %%
precio_fijo_df.describe()
# Out:
#        Precio_Potencia_P1  Precio_Potencia_P2  Precio_Potencia_P3  \
# count          162.000000           54.000000           54.000000
# mean            44.146416           30.464010           12.329643
# std              7.235367            6.083269            3.999114
# min             38.043260           24.437330            8.367730
# 25%             38.043426           24.437330            8.367731
# 50%             42.586800           30.464010           12.329643
# 75%             44.444710           36.490689           16.291555
# max             59.173470           36.490690           16.291560
#
#        Precio_Potencia_P4  Precio_Potencia_P5  Precio_Potencia_P6  \
# count          162.000000           54.000000           54.000000
# mean            44.146416           30.464010           12.329643
# std              7.235367            6.083269            3.999114
# min             38.043260           24.437330            8.367730
# ...

# %%
sns.pairplot(precio_fijo_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7651d31c3ff9> in <module>
# ----> 1 sns.pairplot(precio_fijo_df)
#
# NameError: name 'sns' is not defined

# %%
precio_fijo_df.corr()
# Out:
#                     Precio_Potencia_P1  Precio_Potencia_P2  \
# Precio_Potencia_P1            1.000000            1.000000
# Precio_Potencia_P2            1.000000            1.000000
# Precio_Potencia_P3           -1.000000           -1.000000
# Precio_Potencia_P4            1.000000            1.000000
# Precio_Potencia_P5            1.000000            1.000000
# Precio_Potencia_P6           -1.000000           -1.000000
# Precio_Energía_P1            -0.108142           -0.080763
# Precio_Energía_P2            -0.044590           -0.045037
# Precio_Energía_P3            -0.160228           -0.020543
# Precio_Energía_P4            -0.108142           -0.080763
# Precio_Energía_P5            -0.044590           -0.045037
# Precio_Energía_P6            -0.160228           -0.020543
#
#                     Precio_Potencia_P3  Precio_Potencia_P4  \
# Precio_Potencia_P1           -1.000000            1.000000
# Precio_Potencia_P2           -1.000000            1.000000
# ...

# %%
precio_fijo_df["Comercializadora"].unique()
# Out:
# array(['CYE', 'Sun_Air_One', 'Audax', 'Opcion'], dtype=object)

# %%
precio_fijo_df["Tarifa"].unique()
# Out:
# array(['2.0. A', '2.0. DHA', '2.1. A', '2.1. DHA', '3.0. A', '3.1. A'],
#       dtype=object)

# %%
precio_fijo_df["Fecha Inicio"].unique()
# Out:
# array(['16.11.2020', '11.06.2020', '08.09.2020', '05.08.2020',
#        '17.11.2020', '01.12.2020', '03.11.2020', '05.10.2020',
#        '06.07.2020', '01.05.2020', '01.04.2020', '01.03.2020',
#        '01.02.2020', '01.01.2020', '01.12.2019', '01.11.2019',
#        '01.10.2019', '01.09.2019', '01.08.2019', '01.07.2019',
#        '01.06.2019', '01.05.2019', '01.04.2019'], dtype=object)

# %%
precio_fijo_df["Fecha Finalización"].unique()
# Out:
# array([nan, '16.11.2020', '08.09.2020', '17.11.2020', '01.12.2020',
#        '03.11.2020', '05.10.2020', '05.08.2020', '06.07.2020',
#        '11.06.2020', '01.05.2020', '01.04.2020', '01.03.2020',
#        '01.02.2020', '01.01.2020', '01.12.2019', '01.11.2019',
#        '01.10.2019', '01.09.2019', '01.08.2019', '01.07.2019',
#        '01.06.2019', '01.05.2019', '01.04.2019'], dtype=object)

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# #### Changing Column Names

# %% [markdown]
# I change the column name to match the other price dataframe.

# %%
precio_fijo_df["Fecha Finalización"] = precio_fijo_df["Fecha_Finalización"]

# %%
precio_fijo_df["Fecha Inicio"] = precio_fijo_df["Fecha_Inicio"]

# %% [markdown]
# #### Managing NaN

# %% [markdown]
# First we substitue the Price NaNs for value 0, as the price for that period is 0.

# %% [markdown]
# Then we create a function that adds the NaN values of Fecha_Finalización with the last date from the column Fecha_Inicio grouping_by the same column "Comercializadora"

# %% [markdown]
# #### Changing all "Precio" columns values  that are  MWh/€ to KWh/€

# %% [markdown]
# All values higher than 0 we divide by 1000 to transform to KWh.
